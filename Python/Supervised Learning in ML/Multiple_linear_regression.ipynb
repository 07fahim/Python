# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("D:/Udemy-GenAI/SalaryMulti.csv")
dataset.head()
# Out:
#    Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                 7                     2                           4
# 1                 4                     0                           2
# 2                13                     4                           8
# 3                11                     3                           2
# 4                 8                     1                           6
#
#    Certifications         Salary
# 0               1   77318.070547
# 1               3   64951.950980
# 2               3  106058.185204
# 3               1   89649.944851
# 4               3   82206.019687

# %%
dataset.shape
# Out:
# (1000, 5)

# %%
sns.pairplot(dataset,hue="Salary")

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# Total Experience              0
# Team Lead Experience          0
# Project Manager Experience    0
# Certifications                0
# Salary                        0
# dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset['Salary']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# y=mx+c

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 94.0614842359922

# %%
lr.predict(x_test)
# Out:
# array([109210.38407843,  76699.34791527,  72198.61195967,  98477.27714231,
#        100823.8207706 ,  53757.52026841,  62978.06611404,  68634.32975189,
#         90062.13725619,  71595.23031604, 118765.30430558, 108211.71943336,
#         95334.09318484,  74416.86912906, 110764.50775902,  84458.56827543,
#         82267.42863225,  65015.49894219,  58463.0418693 ,  91743.99572818,
#         54871.48536056, 100156.37428489,  65015.49894219,  64207.33165328,
#        100593.21987643,  63349.38781142, 104824.94856991,  60129.15300007,
#         54871.48536056,  55242.80705794,  82457.92598839,  95154.72789568,
#         61683.27668065,  75790.16846841,  76852.89795555, 106699.15834288,
#         73674.2257343 ,  95116.47830248,  78189.24997904,  93219.6095028 ,
#         84625.10432752,  66518.38701777,  79098.4294259 ,  74045.54743168,
#        103632.63034655,  69159.20148955,  71827.29026229,  67683.58771493,
# ...

# %%
y_pred=lr.predict(x_test)

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x=dataset['Total Experience'], y=dataset['Salary'], label='Original Data')

# Plotting the prediction line using test data
plt.plot(x_test['Total Experience'], y_pred, color='red', label='Prediction Line')

plt.legend()
plt.title("Multiple Linear Regression Prediction")
plt.xlabel("Total Experience")
plt.ylabel("Salary")
plt.savefig("predict.jpg")
plt.show()
