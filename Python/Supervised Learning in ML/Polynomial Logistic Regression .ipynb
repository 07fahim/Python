# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("D:/Udemy-GenAI/ushape.csv")
dataset['0.000000000000000000e+00'].astype(int)
dataset.head()
# Out:
#    3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                  2.115098                 -0.046244
# 1                  0.882490                 -0.075756
# 2                 -0.055144                 -0.037332
# 3                  0.829545                 -0.539321
# 4                  2.112857                  0.662084
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
sns.pairplot(dataset,hue='0.000000000000000000e+00')
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset['0.000000000000000000e+00']

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=3)
pf.fit(x)
x=pd.DataFrame(pf.transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
lr.coef_,lr.intercept_
# Out:
# (array([[-1.99807680e-04,  4.67430666e-02, -1.53685997e+00,
#          -1.45517645e+00, -9.39804511e-01, -5.02588848e-01,
#           1.31696698e+00, -2.98804075e-01,  3.34348948e-01,
#          -1.01477767e+00]]),
#  array([0.49764108]))

# %%
x.shape
# Out:
# (99, 10)
