# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("D:/Udemy-GenAI/Employee_Salary2.csv")
dataset.head()
# Out:
#    Years of Experience       Salary
# 0             1.000000  40000.00000
# 1             2.257942  65979.42119
# 2             2.450875  67253.57549
# 3             2.498713  67342.43510
# 4             2.613729  70532.20448

# %%
dataset.shape
# Out:
# (2000, 2)

# %%
sns.pairplot(dataset)

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="Years of Experience",y='Salary',data=dataset)
plt.show()

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
x=dataset[['Years of Experience']]
y=dataset['Salary']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)
pf.fit(x)
x=pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# y=mx+c

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 99.89513619008181

# %%
lr.predict(x)
# Out:
# array([ 40057.39997076,  64343.60941354,  67135.45013013, ...,
#        437380.86989418, 482506.52620737, 497813.34691744])

# %%
y_pred=lr.predict(x)

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Years of Experience",y='Salary',data=dataset)
plt.plot(dataset['Years of Experience'],y_pred,c='red')
plt.legend("Original","Predict Line")
plt.savefig("predict1.jpg")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6392\4072246023.py:4: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend("Original","Predict Line")

# %%
test=pf.transform([[1.000000]])
test
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1., 1., 1., 1.]])

# %%
lr.predict(test)
# Out:
# array([40057.39997076])
