# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("D:/Udemy-GenAI/Social_Network_Ads.csv")
dataset.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 371   60            83000          1
# 31    27           137000          1
# 122   40            75000          0
# 38    26            72000          0
# 377   42            53000          0

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
dataset.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
sns.pairplot(dataset,hue='Purchased')
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset['Purchased']

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

dc=DecisionTreeClassifier()
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dc.score(x_test,y_test)*100
# Out:
# 83.75

# %%
dc.predict([[60,8300]])
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dc)
plt.show()
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier

dc1=DecisionTreeClassifier(criterion="entropy")
dc1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dc1.score(x_test,y_test)*100
# Out:
# 83.75

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dc1)
plt.show()
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,20))
plot_tree(dc)
# Out:
# [Text(0.5436046511627907, 0.9666666666666667, 'x[0] <= 0.654\ngini = 0.46\nsamples = 320\nvalue = [205, 115]'),
#  Text(0.32558139534883723, 0.9, 'x[1] <= 0.61\ngini = 0.3\nsamples = 234\nvalue = [191, 43]'),
#  Text(0.43459302325581395, 0.9333333333333333, 'True  '),
#  Text(0.18604651162790697, 0.8333333333333334, 'x[0] <= -0.11\ngini = 0.07\nsamples = 193\nvalue = [186.0, 7.0]'),
#  Text(0.16279069767441862, 0.7666666666666667, 'gini = 0.0\nsamples = 126\nvalue = [126, 0]'),
#  Text(0.20930232558139536, 0.7666666666666667, 'x[1] <= 0.404\ngini = 0.187\nsamples = 67\nvalue = [60, 7]'),
#  Text(0.18604651162790697, 0.7, 'x[1] <= -0.066\ngini = 0.165\nsamples = 66\nvalue = [60, 6]'),
#  Text(0.16279069767441862, 0.6333333333333333, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.20930232558139536, 0.6333333333333333, 'x[0] <= 0.367\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.11627906976744186, 0.5666666666666667, 'x[1] <= 0.022\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.09302325581395349, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13953488372093023, 0.5, 'x[0] <= 0.272\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.11627906976744186, 0.43333333333333335, 'x[1] <= 0.14\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.046511627906976744, 0.36666666666666664, 'x[0] <= 0.176\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.023255813953488372, 0.3, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.06976744186046512, 0.3, 'x[1] <= 0.052\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.046511627906976744, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09302325581395349, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18604651162790697, 0.36666666666666664, 'x[0] <= 0.176\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.16279069767441862, 0.3, 'x[1] <= 0.287\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.13953488372093023, 0.23333333333333334, 'x[1] <= 0.184\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.09302325581395349, 0.16666666666666666, 'x[0] <= 0.033\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06976744186046512, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11627906976744186, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18604651162790697, 0.16666666666666666, 'x[1] <= 0.242\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.16279069767441862, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20930232558139536, 0.1, 'x[0] <= 0.033\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18604651162790697, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23255813953488372, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18604651162790697, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20930232558139536, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16279069767441862, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3023255813953488, 0.5666666666666667, 'x[1] <= 0.287\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0